# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Veronica Mwihaki
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# #Exploring the Properties of Top Performing Films for Microsoft's New Movie Studio
#
# ##Business Problem
# Microsoft has limited experiences in making movies and have  tasked me in exploring different data sets and the data files like titles genres,ratings,budgets and gross. In order to come up with the best findings on how different movie properties contibute in there box office performance that will help contribute to the what type of movies will be created.
#
# ##Data Sources

# %%
# imports
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data files 
basics = pd.read_csv("zippedData/imdb.title.basics.csv.gz")
ratings = pd.read_csv("zippedData/imdb.title.ratings.csv.gz")
gross = pd.read_csv("zippedData/bom.movie_gross.csv.gz")
budgets = pd.read_csv("zippedData/tn.movie_budgets")
